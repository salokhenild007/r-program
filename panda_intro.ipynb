# %%
import pandas as pd
'''
Pandas is a Python library that provides high-performance, easy-to-use data structures and data analysis tools for working with "relational" or "labeled" data. It is built on top of NumPy and is intended to be the fundamental high-level building block for doing practical, real-world data analysis in Python.
'''
# Out:
# '\nPandas is a Python library that provides high-performance, easy-to-use data structures and data analysis tools for working with "relational" or "labeled" data. It is built on top of NumPy and is intended to be the fundamental high-level building block for doing practical, real-world data analysis in Python.\n'

# %%
dir(pd) #pd is a shortcut for panda
#dir is directry where all operation in padas shows as follow
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %% [markdown]
# data fram

# %%
df=pd.read_csv("/content/sample_data/california_housing_train.csv")
#dataset avilable in sample data in folder
#in jupitor we need to download from colab
#california hosusong csv file is inbuilt file of sample in goole colab
#to read csv file we use follow sybtax

# %%
df.head(15) #head show frisr data from 15
#df is a df is name of a data frame we can use any for this
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# ...

# %%
df.tail(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16990      1530.0       653.0         1.7038             78300.0
# ...

# %%
df=pd.read_csv("/content/Salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.columns #print all colums
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes #display all datatypes of columns
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info() #display all info od dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df['rank'] # we can show only colum details using this cmd
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.describe() #it show all numerical column
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max() #it shows all max values of all column
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min() #it shows all min values of column
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean() #it shows mean of a all column
# Out:
# <ipython-input-15-0c38e0506f13>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean() #it shows mean of a all column
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.phd.mean() #when we want perticular colume info or mean
# Out:
# 19.705128205128204

# %%
df.phd.describe() #all detail of phd column print here
# describe column only show the detail of numeric column
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.quantile(0.25)
# Out:
# 10.25

# %%
df.phd.quantile(0.50)
# Out:
# 18.5

# %%
df.max() # max can show all max values in column
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.std() #std deviation calculated
# Out:
# <ipython-input-22-0be3c0139dfe>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std() #std deviation calculated
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df_50=df.head(50)

# %%
df_50
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df_50.mean()
# Out:
# <ipython-input-25-abcf5df04292>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_50.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-26-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.head(50).mean()
# Out:
# <ipython-input-27-56442511a41d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.salary #we open colum using dataframe . columnname
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary'] # will work if column name has blank space or dot eg. df["No. of Columns"]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
#storage of data and column in a variable we use
result=df.salary
result
#we can add variable and store the output in it as a data in table
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
# 2 data structures in pandas: 1. Series 2. DataFrame
# Pandas Series: is a one-dimensional labeled array whose object size cannot be changed.
#
# Pandas DataFrame: is a two-dimensional structure with columns and rows whose size can be changed.
# You can also think of it as a dictionary of Series objects.
type(result)
# Out:
# pandas.core.series.Series

# %%
#data frame is noting but the table of multiply column and multple rows
#where data series is the data of single colum with multuple values
result
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
result
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
#here we create a 2 columns for in dataset result2  from dataset salary
result2=df[['salary','rank']]
result2
# Out:
#     salary       rank
# 0   186960       Prof
# 1    93000       Prof
# 2   110515       Prof
# 3   131205       Prof
# 4   104800       Prof
# ..     ...        ...
# 73  105450       Prof
# 74  104542  AssocProf
# 75  124312       Prof
# 76  109954       Prof
# 77  109646       Prof
#
# [78 rows x 2 columns]

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
type(result) #type is series
# Out:
# pandas.core.series.Series

# %%
type(result2) #type is dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
#we saw all columns in dataframe salary data frame is nothing but our excel sheet of data
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
newdf=df[['rank','phd','salary']]
#create new data fram using old dataframe columns rank, phd,salary

# %%
newdf
# Out:
#          rank  phd  salary
# 0        Prof   56  186960
# 1        Prof   12   93000
# 2        Prof   23  110515
# 3        Prof   40  131205
# 4        Prof   20  104800
# ..        ...  ...     ...
# 73       Prof   18  105450
# 74  AssocProf   19  104542
# 75       Prof   17  124312
# 76       Prof   28  109954
# 77       Prof   23  109646
#
# [78 rows x 3 columns]

# %%
df['discipline'].value_counts() # category and its value
#discipline is a coumnn name and thisis use for count the perticular column
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
df.phd.describe() # to discribe all elemnets in a single column we use describe
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.rank.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-c69906c47a63> in <cell line: 1>()
# ----> 1 df.rank.describe()
#
# AttributeError: 'function' object has no attribute 'describe'

# %%
df.phd.count()
# Out:
# 78

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
# in rank 3 values: Asso,Asst,Prof. Group by this and find mean of each category
df.groupby(['rank']).mean()
 # group by rank and finds mean of all numeric columns
# Out:
# <ipython-input-52-b084c9977610>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['rank']).mean()
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['sex']).mean()
# Out:
# <ipython-input-53-f1f0eb4b7e52>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex']).mean()
#               phd    service         salary
# sex
# Female  16.512821  11.564103  101002.410256
# Male    22.897436  18.538462  115045.153846

# %%
df.groupby(['discipline']).count()
# Out:
#             rank  phd  service  sex  salary
# discipline
# A             36   36       36   36      36
# B             42   42       42   42      42

# %%
df.groupby(["discipline","rank"]).count()
# Out:
#                       phd  service  sex  salary
# discipline rank
# A          AssocProf    5        5    5       5
#            AsstProf     8        8    8       8
#            Prof        23       23   23      23
# B          AssocProf    8        8    8       8
#            AsstProf    11       11   11      11
#            Prof        23       23   23      23

# %%
df.groupby(["rank","sex","discipline"]).mean() ## avg sal of discipline B's Male Prof is: 137989.076923
# Out:
#                                    phd    service         salary
# rank      sex    discipline
# AssocProf Female A           18.500000  15.500000   72128.500000
#                  B           13.500000   8.833333   99435.666667
#           Male   A           20.000000  17.000000   81285.000000
#                  B           10.500000   7.500000  113404.000000
# AsstProf  Female A            4.833333   2.500000   72933.333333
#                  B            6.600000   2.600000   84189.800000
#           Male   A            3.000000   1.000000   79000.000000
#                  B            4.666667   2.000000   88224.000000
# Prof      Female A           26.500000  16.125000  109631.875000
#                  B           21.500000  17.900000  131836.200000
#           Male   A           28.933333  22.733333  113164.400000
#                  B           29.538462  25.846154  137989.076923

# %%
df.groupby('rank')[["phd","sex"]].mean()
# Out:
# <ipython-input-57-a908d47d187e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('rank')[["phd","sex"]].mean()
#                  phd
# rank
# AssocProf  15.076923
# AsstProf    5.052632
# Prof       27.065217

# %%
df.groupby('rank')[['salary','phd']].mean() # group by rank and find mean of specified columns only
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
grouped=df.groupby('rank') # saving in variable grouped

# %%
grouped

# %%
for g in grouped: # # to display records of grouped variable
  print (g)
# Out:
# ('AssocProf',          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 64  AssocProf          A   26       24  Female   73300
# 71  AssocProf          B   12        9  Female   71065
# 74  AssocProf          B   19        6  Female  104542)
# ('AsstProf',         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 16  AsstProf          B    8        3    Male   75044
# ...

# %%
df[df.salary>160000] #to print the salary of data in excel file shows salary more then 16000
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 72  Prof          B   24       15  Female  161101

# %%
df.shape #it shows the rows and columns in the data fram
# Out:
# (78, 6)

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %%
df[df.salary>160000] #it show salary more then 1600000
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 72  Prof          B   24       15  Female  161101

# %%
df[df.salary>160000].shape[0]  # it shows that no of column in salary more then1600000
# Out:
# 3

# %%
df[df.salary>160000].count() # it shoes which column have how many rows
# Out:
# rank          3
# discipline    3
# phd           3
# service       3
# sex           3
# salary        3
# dtype: int64

# %%
# Create a dataframe having all Males whose salary is > 1,50,000/-



newdf=df[(df['sex']=='Male') & (df['salary']>150000)]

# %%
newdf
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
# newdf.count()
# OR
newdf.shape[0]
# Out:
# 7

# %%
newdf.shape
# Out:
# (7, 6)

# %%
# Create a dataframe having all Males whose salary is > 1,50,000/-
newdf=df[(df['sex']=='Male') & (df['salary']>150000)]

# %%
newdf
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
df[df['rank']!='prof'].shape
# Out:
# (78, 6)

# %%
df[df['rank']!='prof'].count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
df[df['rank']!='prof'].shape[0]
# Out:
# 78

# %%
df[df['rank']!='Prof'].shape
# Out:
# (32, 6)

# %%
df[df['rank']!='Prof'].shape[0]
# Out:
# 32

# %%
df[(df['service']>15) | (df['salary']>100000)]
#df[(df['service']>15) | (df['salary']>100000)].shape[0]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# ...

# %%
df[(df['service']>20) | (df['salary']>160000)]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 3        Prof          A   40       31    Male  131205
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# 27       Prof          A   45       43    Male  155865
# 31       Prof          B   22       21    Male  155750
# 35       Prof          B   28       23    Male  126933
# 36       Prof          B   45       45    Male  146856
# 40       Prof          A   39       36  Female  137000
# 45       Prof          B   25       25  Female  140096
# ...

# %%
df[(df['service']>20) | (df['salary']>160000)].shape
# Out:
# (21, 6)

# %%
df[(df['service']>20) | (df['salary']>160000)].count()
# Out:
# rank          21
# discipline    21
# phd           21
# service       21
# sex           21
# salary        21
# dtype: int64

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
# for output of a 5th row we cant use this so we use iloc
df.shape[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-2d27201e44e4> in <cell line: 2>()
#       1 # for output of a 5th row we cant use this so we use iloc
# ----> 2 df.shape[5]
#
# IndexError: tuple index out of range

# %%
df.iloc[5]
# Out:
# rank            Prof
# discipline         A
# phd               20
# service           20
# sex             Male
# salary        122400
# Name: 5, dtype: object

# %%
df.iloc[77] # iloc -> index location for row
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[1:4, 0:3]  # row 1 to 3, col 0 to 2
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40

# %%
df.iloc[4,2]
# Out:
# 20

# %%
df.iloc[]
# Out:
#   File "<ipython-input-97-75d2b8f5a532>", line 1
#     df.iloc[]
#             ^
# SyntaxError: invalid syntax

# %%
df.iloc[0:10,0:3] # 0 to 9 records, 0 to 2 columns
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
df.iloc[0:2,] # rows 0 to 1 and all columns, Or df.iloc[0:2]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[:,4] #all rows, index 4 column
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
df.iloc[:,0:3]
# Out:
#          rank discipline  phd
# 0        Prof          B   56
# 1        Prof          A   12
# 2        Prof          A   23
# 3        Prof          A   40
# 4        Prof          B   20
# ..        ...        ...  ...
# 73       Prof          B   18
# 74  AssocProf          B   19
# 75       Prof          B   17
# 76       Prof          A   28
# 77       Prof          A   23
#
# [78 rows x 3 columns]

# %%
df.iloc[:,0:2]
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# ..        ...        ...
# 73       Prof          B
# 74  AssocProf          B
# 75       Prof          B
# 76       Prof          A
# 77       Prof          A
#
# [78 rows x 2 columns]

# %%
df.iloc[0,5]
# Out:
# 186960

# %%
df.iloc[77]
#it show loc of 77th raw with all column
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[1:4, 0:3]  # row 1 to 3, col 0 to 2
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40

# %%
df.iloc[1:3,0:2] #(row 1:3,column 0:2)
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
df.iloc[0:9,0:4] # 0 means all rows and columns to 4th columns and 9th row
# Out:
#         rank discipline  phd  service
# 0       Prof          B   56       49
# 1       Prof          A   12        6
# 2       Prof          A   23       20
# 3       Prof          A   40       31
# 4       Prof          B   20       18
# 5       Prof          A   20       20
# 6  AssocProf          A   20       17
# 7       Prof          A   18       18
# 8       Prof          A   29       19

# %%
df.iloc[,]
# Out:
#   File "<ipython-input-110-6d456764b40b>", line 1
#     df.iloc[,]
#             ^
# SyntaxError: invalid syntax

# %%
df.iloc[0:2,] # rows 0 to 1 and all columns, Or df.iloc[0:2]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[:,4] #all rows, index 4 column
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
df.iloc[:,0:3]
# Out:
#          rank discipline  phd
# 0        Prof          B   56
# 1        Prof          A   12
# 2        Prof          A   23
# 3        Prof          A   40
# 4        Prof          B   20
# ..        ...        ...  ...
# 73       Prof          B   18
# 74  AssocProf          B   19
# 75       Prof          B   17
# 76       Prof          A   28
# 77       Prof          A   23
#
# [78 rows x 3 columns]

# %%
df.iloc[[10,20,22,24],] # only particular rows with all columns df.iloc[[10,20,22,24]]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 20  AsstProf          B    4        4  Male   92000
# 22  AsstProf          A    4        2  Male   73000
# 24      Prof          A   30       23  Male   91100

# %%
df.iloc[[10,20,25,30]]
# Out:
#          rank discipline  phd  service   sex  salary
# 10       Prof          B   39       33  Male  128250
# 20   AsstProf          B    4        4  Male   92000
# 25       Prof          B   35       31  Male   99418
# 30  AssocProf          B    9        7  Male  107008

# %% [markdown]
# when we dont no exact index loc use loc where iloc bcoz iloc stand for index loc where loc find lloc of data

# %%
df.loc[:,["rank","phd"]]
# Out:
#          rank  phd
# 0        Prof   56
# 1        Prof   12
# 2        Prof   23
# 3        Prof   40
# 4        Prof   20
# ..        ...  ...
# 73       Prof   18
# 74  AssocProf   19
# 75       Prof   17
# 76       Prof   28
# 77       Prof   23
#
# [78 rows x 2 columns]

# %%
df.loc[:,"rank"]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.loc[[1,2,3,4],["rank","phd"]]
# Out:
#    rank  phd
# 1  Prof   12
# 2  Prof   23
# 3  Prof   40
# 4  Prof   20

# %%
df.loc[10:30:4]
# Out:
#          rank discipline  phd  service   sex  salary
# 10       Prof          B   39       33  Male  128250
# 14       Prof          B   25       19  Male  153750
# 18       Prof          A   19        7  Male  107300
# 22   AsstProf          A    4        2  Male   73000
# 26       Prof          A   38       19  Male  148750
# 30  AssocProf          B    9        7  Male  107008

# %%
df.iloc[::-1] # all records in reverse order
# Out:
#          rank discipline  phd  service     sex  salary
# 77       Prof          A   23       15  Female  109646
# 76       Prof          A   28       14  Female  109954
# 75       Prof          B   17       17  Female  124312
# 74  AssocProf          B   19        6  Female  104542
# 73       Prof          B   18       10  Female  105450
# ..        ...        ...  ...      ...     ...     ...
# 4        Prof          B   20       18    Male  104800
# 3        Prof          A   40       31    Male  131205
# 2        Prof          A   23       20    Male  110515
# 1        Prof          A   12        6    Male   93000
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %% [markdown]
# Aggregation Function in Pandas Aggreation - Computing a summary statistic about each group

# %%
dir(df) # functions that can be applied on dataframe
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %% [markdown]
# Common aggregation functions are:min,max,count,sum,prod,mean,median,mode,mad,std,var

# %%
 #Compute group sums or means
# Compute group sizes or counts
# agg() or aggregate()  - useful when multiple statistics are computed per column
# Here's how to calculate the Mean Absolute Deviation - mad().
#Step 1: Calculate the mean.
#Step 2: Calculate how far away each data point is from the mean using positive distances. These are called absolute deviations.
#Step 3: Add those deviations together.
#Step 4: Divide the sum by the number of data points.

df[['phd','salary']].agg(['min','mean','max','mad','std'])
# Out:
# <ipython-input-129-63bf3d0d377c>:10: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['phd','salary']].agg(['min','mean','max','mad','std'])
# <ipython-input-129-63bf3d0d377c>:10: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['phd','salary']].agg(['min','mean','max','mad','std'])
#             phd         salary
# min    1.000000   57800.000000
# mean  19.705128  108023.782051
# max   56.000000  186960.000000
# mad    9.920776   22957.266930
# std   12.498425   28293.661022

# %%
df[['salary']].agg('skew')
# Out:
# salary    0.452103
# dtype: float64

# %%
df[['salary']].agg('kurt')
# Out:
# salary   -0.401713
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-132-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# phd        1.562106e+02
# service    1.473740e+02
# salary     8.005313e+08
# dtype: float64

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.sem() #std error of mean - Standard error i.e.Sigma / square root of n
# Out:
# <ipython-input-134-cc3faf423f7b>:1: FutureWarning: The default value of numeric_only in DataFrame.sem is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sem() #std error of mean - Standard error i.e.Sigma / square root of n
# phd           1.415168
# service       1.374558
# salary     3203.626259
# dtype: float64

# %%
for i in range(1, 100):
    if i % 2 != 0:
        print('weird', i)
    else:
        print('Odd Number:', i)
# Out:
# Even Number: 1
# Odd Number: 2
# Even Number: 3
# Odd Number: 4
# Even Number: 5
# Odd Number: 6
# Even Number: 7
# Odd Number: 8
# Even Number: 9
# Odd Number: 10
# Even Number: 11
# Odd Number: 12
# Even Number: 13
# Odd Number: 14
# Even Number: 15
# Odd Number: 16
# Even Number: 17
# Odd Number: 18
# Even Number: 19
# Odd Number: 20
# Even Number: 21
# Odd Number: 22
# Even Number: 23
# Odd Number: 24
# Even Number: 25
# Odd Number: 26
# Even Number: 27
# Odd Number: 28
# Even Number: 29
# Odd Number: 30
# Even Number: 31
# Odd Number: 32
# Even Number: 33
# Odd Number: 34
# Even Number: 35
# Odd Number: 36
# Even Number: 37
# Odd Number: 38
# Even Number: 39
# Odd Number: 40
# Even Number: 41
# Odd Number: 42
# Even Number: 43
# Odd Number: 44
# Even Number: 45
# Odd Number: 46
# Even Number: 47
# Odd Number: 48
# Even Number: 49
# Odd Number: 50
# Even Number: 51
# Odd Number: 52
# Even Number: 53
# Odd Number: 54
# Even Number: 55
# Odd Number: 56
# Even Number: 57
# ...
